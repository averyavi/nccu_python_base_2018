# %% [markdown]
# # Python基礎練習
#
# 本教材編撰來源系來自[Codecademy](https://www.codecademy.com/)，原設計為Python 2之語系，本練習系提供離線使用，並將之中文化且優化為python 3。2與3差異不大，同學可自行前往原始網站進行互動學習。若初學者，可以使用本教材，避免語言的隔閡後，再到原始網站練習，得到更深層的學習成果。
#
# ## 練習目標單元part_1:
#
# 1. Python基礎語法
#
# 2. 字串(Strings)及輸出(Console Output)
#
# 3. 條件式(Conditionals)及流程控制(Control Flow)
#
# 4. 功能函式(Functions)
#
# ## 練習目標單元part_2:
#
# 5. 列表(Lists)及字典(Dictionaries)
#
# 6. 由學生轉變為老師
#
# 7. 列表(Lists)及功能函式(Functions)
#
# 8. 循環(Loops)

# %% [markdown]
# # 以下為part_2
# # 6 Student Becomes the Teacher 教學相長~ 練習內容
# ## ---------------------------------------------------------------------------------------------------

# %% [markdown]
# # Learn 1/9
#
# ## 教學相長
#
# ### 第一課
#
#
# 歡迎來到這個“挑戰課程”。 到現在為止，我們一直領導著你，並且在一些簡短而相對容易的項目上工作。 這是一個挑戰，所以要做好準備。 我們相信你！
# 我們會稍微改變它，讓你成為你自己班的老師。 為您的所有學生製作成績冊。
#
#     animal = {
#       "name": "Mr. Fluffles",
#       "sounds": ["meow", "purr"]
#     }
#     print (animal["name"])
#
# 上面的例子只是提醒你如何創建一個字典，然後呼叫name鍵儲存的項目。
#
# # Instructions 1/9
#
# 1. 創建三本詞典：lloyd, alice, and tyler。
# 2. 為每本詞典提供"name", "homework", "quizzes", and "tests"等鍵(key)。
# 3. “name”鍵是學生的名字（也就是說，lloyd的名字應該是“Lloyd”），其他鍵應該是空列表（我們很快就會填寫這些列表！）

# %%
#練習開始

# %% [markdown]
#     #不要直接看答案 先練習看看
#
#     lloyd = {
#       "name" : "Lloyd",
#       "homework" : [],
#       "quizzes" : [],
#       "tests" : []
#     }
#
#     alice = {
#       "name" : "Alice",
#       "homework" : [],
#       "quizzes" : [],
#       "tests" : []
#     }
#
#     tyler = {
#       "name" : "Tyler",
#       "homework" : [],
#       "quizzes" : [],
#       "tests" : []
#     }

# %% [markdown]
# # Learn 2/9
#
#
# ## 教學相長
#
# ### 分數是多少？
#
#
# 做得好！
#
#
# # Instructions 2/9
#
# 現在填寫底下提供的內容到詞典lloyd。為了節省你一些時間，我們已經為你填補了其他人剩下的部分。
#
# Homework: 90.0, 97.0, 75.0, 92.0
# Quizzes: 88.0, 40.0, 94.0
# Test Scores: 75.0, 90.0
#
# 請在填寫時，讓數字包含小數點，以便讓您的成績以浮點形式儲存！ 稍後可以看出這個重要性。

# %%
# 練習看看 
lloyd = {
  "name": "Lloyd",
  "homework": [],
  "quizzes": [],
  "tests": []
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# %% [markdown]
#     # 忍耐一下 不要直接看答案
#
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0 ,92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }

# %% [markdown]
# # Learn 3/9
#
#
# ## 教學相長
#
#
# ### 擺在一起看看
#
# 現在讓我們把三個字典放在一個列表中。
#
#      my_list = [1，2，3]
#
# 上面的例子只是提示如何創建一個列表。 之後，my_list應包含1，2和3。
#
# # Instructions 3/9
#
# 在你下面的代碼，建一個名為students的列表，其中包含lloyd，alice和tyler。

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0 ,92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

#這裡開始你的程式內容

# %% [markdown]
#     #### 試看看 不要直接看答案
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0 ,92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     students = [lloyd, alice, tyler]

# %% [markdown]
# # Learn 4/9
#
# ## 教學相長
#
# ### 印出存查記錄
#
# 優秀。 現在你需要一份印有所有學生成績的印刷文件。
#
#     animal_sounds = {
#       "cat": ["meow", "purr"],
#       "dog": ["woof", "bark"],
#       "fox": [],
#     }
#     print (animal_sounds["cat"])
#
# 上面的例子只是提醒你如何創建一個字典，然後存取由"cat"鍵儲存的項目內容。
#
# # Instructions 4/9
#
# 為您的學生列表students中的每個學生student印出該學生(student)的數據，如下所示：
#
# 印出學生的name
# 印出學生的homework
# 印出學生的quizzes
# 印出學生的tests

# %%
#學習的例子

def count_small(numbers):
  total = 0
  for n in numbers:
    if n < 10:
      total = total + 1
  return total

lotto = [4, 8, 15, 16, 23, 42]
small = count_small(lotto)
print (small)
# Out:
# 2

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0 ,92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

students = [lloyd, alice, tyler]

#從這裡開始寫

# %% [markdown]
#     #### 試看看 不要直接看答案
#
#
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0 ,92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     students = [lloyd, alice, tyler]
#
#     for student in students:
#       print (student["name"])
#       print (student["homework"])
#       print (student["quizzes"])
#       print (student["tests"])

# %% [markdown]
# # Learn 5/9
#
# ## 教學相長
#
# ### 來建立一個平均值的函式吧
#
# 在教授課程時，有個重要的事情是要拿出學生的平均數來分配成績，因為.......有時候課程太過困難或太過簡單。
#
#     5 / 2
#     # 2
#
#     5.0 / 2
#     # 2.5
#
#     float(5) / 2
#     # 2.5
#
# 上面的例子提醒了Python如何在分區中工作。
#
#      *當用一個整數除整數時，結果總是一個整數（無條件捨去）。
#      *當你用整數除一個浮點數(float)時，結果總是一個浮點數(float)。
#      *要強迫python進行浮點運算時，你也可以使用float()將其中一個整數轉換為float即可進行浮點運算。
#
# # Instructions 5/9
#
# 寫出一個平均值average函數，其中輸入應為數字的列表型態，該函數最終應該返回平均值average。
#
#      *定義一個名為average的函數，它有一個引數，numbers。
#      *在該函數內部，呼叫內建的函數sum()來進行加總，然後將結果存儲在一個名為total的變量中。
#      *像上面的例子一樣，使用float()來轉換total並將結果存儲在total中。
#      *total除以numbers列表的長度。提示: 可以使用內置的len()函數來計算numbers的長度。
#      *返回result。

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0, 92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# Add your function below!

# %% [markdown]
#     #### 試看看 不要直接看答案
#
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0, 92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     # Add your function below!
#     def average(numbers):
#       total = sum(numbers)
#       total = float(total)
#       return total / len(numbers)

# %% [markdown]
# # Learn 6/9
#
# ## 教學相長
#
# ### 加上權重後，你會看到甚麼?
#
# 現在我們需要使用加權平均來計算學生的平均數。
#
#     cost = {
#         "apples": [3.5, 2.4, 2.3],
#         "bananas": [1.2, 1.8],
#     }
#
#     return 0.9 * average(cost["apples"]) + \
#     0.1 * average(cost["bananas"])
#
# 1. 在上面的例子中，我們創建了一個名為cost的字典，其中包含一些水果的成本。
# 2. 然後，我們計算蘋果的平均成本和香蕉的平均成本。 由於我們喜歡蘋果遠遠超過我們喜歡的香蕉，我們讓蘋果的平均成本佔9成，但香蕉的平均成本佔1成。
#
# \這個符號扮演一個延續的角色。 結尾\之後的下面一行被認為是目前的延續。
#
# # Instructions 6/9
#
# 編寫一個名為get_average的函數，它以學生字典(student-如lloyd, alice, 或 tyler)作為輸入並返回每個學生的加權平均值。
#
#      *定義一個名為get_average的函數，它接受一個名為student的引數。
#      *定義一個變數homework，它用來存student["homework"]的平均成績average()。
#      *對"quizzes" 和 "tests"重複上述步驟。
#      *將3個平均值乘以它們的權重並返回這三個的和。 Homework佔10％，測驗quizzes為30％，測試tests為60％。

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0, 92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# Add your function below!
def average(numbers):
  total = sum(numbers)
  total = float(total)
  return total / len(numbers)

#### 從這裡開始寫

# %% [markdown]
# #### 試看看 不要直接看答案
#
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0, 92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     # Add your function below!
#     def average(numbers):
#       total = sum(numbers)
#       total = float(total)
#       return total / len(numbers)
#
#     def get_average(student):
#       homework = average(student["homework"])
#       quizzes = average(student["quizzes"])
#       tests = average(student["tests"])
#
#       total = homework *.1 + quizzes * .3 + tests * .6
#       return total

# %% [markdown]
# # Learn 7/9
#
# ## 教學相長
#
# ### 發送成績單
#
# 做得好！
# 現在我們來編寫一個get_letter_grade函數，它將score作為輸入，並返回一個該學生應該得到的成績字母等級。
#
# # Instructions 7/9
#
# 定義一個名為get_letter_grade的新函數，它有一個名為score的引數。 預計分數score是一個數字。
# 在函數內部，使用 if: / elif: / else: 語句來檢測分數，如下所示：
#
#     *If score is 90 or above: return "A"
#     *Else if score is 80 or above: return "B"
#     *Else if score is 70 or above: return "C"
#     *Else if score is 60 or above: return "D"
#     *Otherwise: return "F"
#
# 最後，測試你的功能！
# 印出分數字母等級。 呼叫get_letter_grade函數並傳入get_average(lloyd)。

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0, 92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# Add your function below!
def average(numbers):
  total = sum(numbers)
  total = float(total)
  return total/len(numbers)

def get_average(student):
  homework = average(student["homework"])
  quizzes = average(student["quizzes"])
  tests = average(student["tests"])
  return 0.1 * homework + 0.3 * quizzes + 0.6 * tests

#### 從這裡開始寫

# %% [markdown]
#     #### 試看看 不要直接看答案
#
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0, 92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     # Add your function below!
#     def average(numbers):
#       total = sum(numbers)
#       total = float(total)
#       return total/len(numbers)
#
#     def get_average(student):
#       homework = average(student["homework"])
#       quizzes = average(student["quizzes"])
#       tests = average(student["tests"])
#       return 0.1 * homework + 0.3 * quizzes + 0.6 * tests
#
#     #### 從這裡開始寫
#     def get_letter_grade(score):
#       if score >= 90:
#         return "A"
#       elif score >=80:
#         return "B"
#       elif score >=70:
#         return "C"
#       elif score >=60:
#         return "D"
#       else:
#         return "F"
#
#     print (get_letter_grade(get_average(lloyd)))

# %% [markdown]
# # Learn 8/9
#
# ## 教學相長
#
# ### 整體的一部分
#
# 好！ 現在我們來計算班級平均值。
# 你需要得到每個學生的平均值，然後計算這些平均值的平均值。
#
# # Instructions 8/9
#
# 定義一個名為get_class_average的函數，它具有一個參數class_list。 你可以期望class_list是一個包含你的三名學生的列表。
#
# 1. 首先，創建一個名為results的空列表。
#
# 2. 對於class_list中的每個學生的內容，計算get_average(student)，然後呼叫results.append()附加到result。
#
# 3. 最後，返回呼叫average()的結果。

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0, 92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# Add your function below!
def average(numbers):
  total = sum(numbers)
  total = float(total)
  return total/len(numbers)

def get_average(student):
  homework = average(student["homework"])
  quizzes = average(student["quizzes"])
  tests = average(student["tests"])
  return 0.1 * homework + 0.3 * quizzes + 0.6 * tests

#程式開始撰寫區

# %% [markdown]
#     #### 試看看 不要直接看答案
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0, 92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     # Add your function below!
#     def average(numbers):
#       total = sum(numbers)
#       total = float(total)
#       return total/len(numbers)
#
#     def get_average(student):
#       homework = average(student["homework"])
#       quizzes = average(student["quizzes"])
#       tests = average(student["tests"])
#       return 0.1 * homework + 0.3 * quizzes + 0.6 * tests
#
#     def get_class_average(class_list):
#       results = []
#       for student in class_list:
#         student_avg = get_average(student)
#         results.append(student_avg)
#       return average(results)

# %% [markdown]
# # Learn 9/9
#
#
# ## 教學相長
#
# ### 最終結果
#
# 真棒！ 你做得很好。 現在讓我們使用您創建的函數來檢查整個課程的成績。
#
# # Instructions 9/9
#
# 1. 創建一個名為學生students的list，並填寫三名學生alice, lloyd, 和 tyler。
# 2. 找到班級的平均成績。 將此數字等級印出。

# %%
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0, 92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

def average(numbers):
  total = sum(numbers)
  total = float(total)
  return total/len(numbers)

def get_average(student):
  homework = average(student["homework"])
  quizzes = average(student["quizzes"])
  tests = average(student["tests"])
  return 0.1 * homework + 0.3 * quizzes + 0.6 * tests

def get_letter_grade(score):
  if score >= 90:
    return "A"
  elif score >=80:
    return "B"
  elif score >=70:
    return "C"
  elif score >=60:
    return "D"
  else:
    return "F"

def get_class_average(class_list):
  results = []
  for student in class_list:
    student_avg = get_average(student)
    results.append(student_avg)
  return average(results)
# 開始你的程式

# %% [markdown]
#     #### 試看看 不要直接看答案
#
#     lloyd = {
#       "name": "Lloyd",
#       "homework": [90.0, 97.0, 75.0, 92.0],
#       "quizzes": [88.0, 40.0, 94.0],
#       "tests": [75.0, 90.0]
#     }
#     alice = {
#       "name": "Alice",
#       "homework": [100.0, 92.0, 98.0, 100.0],
#       "quizzes": [82.0, 83.0, 91.0],
#       "tests": [89.0, 97.0]
#     }
#     tyler = {
#       "name": "Tyler",
#       "homework": [0.0, 87.0, 75.0, 22.0],
#       "quizzes": [0.0, 75.0, 78.0],
#       "tests": [100.0, 100.0]
#     }
#
#     # Add your function below!
#     def average(numbers):
#       total = sum(numbers)
#       total = float(total)
#       return total/len(numbers)
#
#     def get_average(student):
#       homework = average(student["homework"])
#       quizzes = average(student["quizzes"])
#       tests = average(student["tests"])
#       return 0.1 * homework + 0.3 * quizzes + 0.6 * tests
#
#     def get_letter_grade(score):
#       if score >= 90:
#         return "A"
#       elif score >=80:
#         return "B"
#       elif score >=70:
#         return "C"
#       elif score >=60:
#         return "D"
#       else:
#         return "F"
#
#     def get_class_average(class_list):
#       results = []
#       for student in class_list:
#         student_avg = get_average(student)
#         results.append(student_avg)
#       return average(results)
#
#     students = [lloyd, alice, tyler]
#
#     print (get_class_average(students))
