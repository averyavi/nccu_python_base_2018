# %%
import requests
url = 'https://www.facebook.com/'
response = requests.get(url) #請求方法-Get
response.encoding = 'utf-8'
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant" id="facebook" class="no_js">
# ...
