# %% [markdown]
# # Python基礎練習
#
# 本教材編撰來源系來自[Codecademy](https://www.codecademy.com/)，原設計為Python 2之語系，本練習系提供離線使用，並將之中文化且優化為python 3。2與3差異不大，同學可自行前往原始網站進行互動學習。若初學者，可以使用本教材，避免語言的隔閡後，再到原始網站練習，得到更深層的學習成果。
#
# ## 練習目標單元part_1:
#
# 1. Python基礎語法
#
# 2. 字串(Strings)及輸出(Console Output)
#
# 3. 條件式(Conditionals)及流程控制(Control Flow)
#
# 4. 功能函式(Functions)
#
# ## 練習目標單元part_2:
#
# 5. 列表(Lists)及字典(Dictionaries)
#
# 6. 由學生轉變為老師
#
# 7. 列表(Lists)及功能函式(Functions)
#
# 8. 循環(Loops)

# %% [markdown]
# # 以下為part_1
# # 4.2 Functions - Taking a Vacation練習內容
# ## ---------------------------------------------------------------------------------------------------

# %% [markdown]
# # Learn 1/7
#
# ## 休個假吧~
#
# ### 開始前
#
# 我們先快速回顧一下Python中的函數。
#
# def bigger(first, second):
#   print (max(first, second))
#   return True
#
# 在上面的例子中：
#
# 1. 我們定義一個名為bigger的函數，它有兩個引數: first, second。
# 2. 然後，我們使用內建函數max印出兩個引數中較大的一個。
# 3. 最後，函數返回True。
#
# 現在嘗試自己創建一個函數！
#
#
# # Instructions 1/7
#
# 1. 編寫一個名為answer的函數，它不接受任何引數，並且很單純的返回42。
# 2. 即使沒有引數的設計，你仍然需要括號。在函數定義的末尾不要忘記冒號！

# %% [markdown]
# def bigger(first, second):
#   print (max(first, second))
#   return True
# bigger(55,12)

# %%
#1. 編寫一個名為answer的函數，它不接受任何引數，並且很單純的返回42。
#2. 即使沒有引數的設計，你仍然需要括號。在函數定義的末尾不要忘記冒號！

# %%
#試看看 不要直接看答案
def answer():
  return 42

answer()
# Out:
# 42

# %% [markdown]
# # Learn 2/7
#
# ## 休個假吧~
#
# ### 計劃你的旅程
# 在計劃度假時，確切知道要花多少錢是非常重要的。

# %% [markdown]
# #### If I make $8.35/hour...
# def wages(hours):
#
#     return 8.35 * hours

# %% [markdown]
# 上面的例子只是對函數定義的回顧。
# 讓我們用函數來計算你旅行的成本。
#
# # Instructions 2/7
# 1. 定義一個名為hotel_cost的函數，以一個參數night作為輸入。
# 2. 這家酒店每晚收費140美元。 所以，函數hotel_cost應該返回140*多少晚(night)。

# %%
#1. 定義一個名為hotel_cost的函數，以一個參數night作為輸入。
#2. 這家酒店每晚收費140美元。 所以，函數hotel_cost應該返回140*多少晚(night)。

# %%
#試看看 不要直接看答案

def hotel_cost(nights):
  return 140 * nights

hotel_cost(10)
# Out:
# 1400

# %% [markdown]
# # Learn 3/7
#
# ## 休個假吧~
#
# ### 到那兒?
#
# 你將需要搭飛機才能到達你想去的旅遊地點。
#
# def fruit_color(fruit):
#   if fruit == "apple":
#     return "red"
#   elif fruit == "banana":
#     return "yellow"
#   elif fruit == "pear":
#     return "green"
#
# 上面的例子定義了一個水果顏色的函數，你可以看到，這個功能接受fruit作為輸入，輸出為顏色。
#
#
# # Instructions 3/7
#
# 請保留上面的程式結果，繼續往下增加。
#
# 1. 請在下面程式定義一個名為plane_ride_cost的函數，讓它接受一個輸入-city。
# 2. 該函數應根據輸入的程式位置返回不同的價格，類似於上面的水果顏色程式範例。
# 3. 請根據以下是有效的目的地及其對應的價格做函數返回。
#
# "Charlotte": 183
# "Tampa": 220
# "Pittsburgh": 222
# "Los Angeles": 475

# %%
# 1. 請在下面程式定義一個名為plane_ride_cost的函數，讓它接受一個輸入-city。
# 2. 該函數應根據輸入的程式位置返回不同的價格，類似於上面的水果顏色程式範例。

def hotel_cost(nights):
  return 140 * nights

# %%
#### 試看看 不要直接看答案
def hotel_cost(nights):
  return 140 * nights


def plane_ride_cost(city):

  if city == "Charlotte":
    return 183
  elif city == "Tampa":
    return 220
  elif city == "Pittsburgh":
    return 222
  elif city == "Los Angeles":
    return 475

plane_ride_cost("Tampa")

# %% [markdown]
# # Learn 4/7
#
# ## 休個假吧~
#
# ### 交通花費
#
# 到了你想去的城市之後，你還需要一輛出租車才能讓你四處走動。
#
# def finish_game(score):
#   tickets = 10 * score
#   if score >= 10:
#     tickets += 50
#   elif score >= 7:
#     tickets += 20
#   return tickets
#
#
# 在上面的例子中，首先，我們檢查分數是否大於或等於10，如果是，我們給玩家50分獎勵券。
# 接著如果分數大於或等於7，我們給予玩家20個獎勵票。
# 最後，我們返回玩家贏得的總票數。
#
# 請記住，只有在前面的if語句失敗時才會檢查elif語句，如果前面出現過if/elif，則要前面所有if/elif語句失敗時才會檢查最後的elif語句，以此類推。
#
#
# # Instructions 4/7
#
# 1. 保留上面的成果，新定義一個名為rental_car_cost的函數，用days作為輸入。
# 2. 計算出租車的價格:
#
# a. 每租借一天花費40元.
# b. 租超過七天(含)以上，將從總價中得到50元的則扣。
# c. 如果租期超過三天，將從總價中得到20元的則扣。
# d. 你只能拿到其中一種折扣。
# e. 最後返回出租要花多少錢的結果。

# %%
def hotel_cost(nights):
  return 140 * nights


def plane_ride_cost(city):

  if city == "Charlotte":
    return 183
  elif city == "Tampa":
    return 220
  elif city == "Pittsburgh":
    return 222
  elif city == "Los Angeles":
    return 475

plane_ride_cost("Tampa")

#### 從這裡開始寫

# %%
#### 試看看 不要直接看答案

def hotel_cost(nights):
  return 140 * nights

def plane_ride_cost(city):
  if city == "Charlotte":
    return 183
  elif city == "Tampa":
    return 220
  elif city == "Pittsburgh":
    return 222
  elif city == "Los Angeles":
    return 475

def rental_car_cost(days):
  cost = days * 40
  if days >= 7:
    cost -= 50
  elif days >= 3:
    cost -= 20
  return cost

# %% [markdown]
# # Learn 5/7
#
# ## 休個假吧~
#
# ### 好了，把所有東西放一起試試
#
# 太好了，經過上面的計算，我們知道旅程中的每個花費，現在把他們放在一起，我們就可以知道這次旅遊要花多少錢了。
#
# def double(n):
#   return 2 * n
#
# def triple(p):
#   return 3 * p
#
# def add(a, b):
#   return double(a) + triple(b)
#
#
# 1. 我們示範一個簡單的範例: double(n) and triple(p)是個別的函式，他們分別返回輸入值*2跟輸入值*3。注意到，n 和 p是他們的引數。
#
# 2. 我們定義了一個新的函式(add(a, b))，他把前面兩個函式的內容加總後返回，注意到，即使add（a，b）的參數(parameters)名稱與double（n）和triple（p）的參數(parameters)名稱不同，我們仍然可以將它們作為引數(arguments)傳遞給這些函數。
#
# # Instructions 5/7
#
# 1. 以既有的程式碼為基礎，定義一個名為trip_cost的函數，該函數帶有兩個參數(parameters)，分別是city和days，並返回呼叫rental_car_cost（days），hotel_cost（days - 1）和plane_ride_cost（city）函數後的總和。
# 2. 請注意，我們將hotel_costs（）的參數從住幾個夜晚更改為天數-1。因為我們希望trip-cost只取決於兩個參數，所以我們必須將變量(variable)由night轉換為days。
# 3. 如果你打算住在某個地方，那麼你住在那裡的夜晚比你呆在那里的天數要少一次（想像一下週末你出去玩耍的行程，你星期六出發，星期天回來，所以你去兩天，但只住一個晚上）。

# %%
def hotel_cost(nights):
  return 140 * nights

def plane_ride_cost(city):
  if city == "Charlotte":
    return 183
  elif city == "Tampa":
    return 220
  elif city == "Pittsburgh":
    return 222
  elif city == "Los Angeles":
    return 475

def rental_car_cost(days):
  cost = days * 40
  if days >= 7:
    cost -= 50
  elif days >= 3:
    cost -= 20
  return cost

#### 從這裡開始寫

# %% [markdown]
# #### 試看看 不要直接看答案
#
# def hotel_cost(nights):
#   return 140 * nights
#
# def plane_ride_cost(city):
#   if city == "Charlotte":
#     return 183
#   elif city == "Tampa":
#     return 220
#   elif city == "Pittsburgh":
#     return 222
#   elif city == "Los Angeles":
#     return 475
#
# def rental_car_cost(days):
#   cost = days * 40
#   if days >= 7:
#     cost -= 50
#   elif days >= 3:
#     cost -= 20
#   return cost
#
# def trip_cost(city, days):
#   return rental_car_cost(days) + hotel_cost(days - 1) + plane_ride_cost(city)
#
# trip_cost('Pittsburgh', 50)

# %% [markdown]
# # Learn 6/7
#
# ## 休個假吧~
#
# ### 嘿，你從未考慮過的事情之一！
# 你不能指望在度假時只花飛機旅行，酒店和租車。還需要額外的費用，如花式食物或紀念品。
#
# # Instructions 6/7
#
#
# 1. 變動trip_cost的內容，增加第三個引數(argument): spending_money.
# 2. 變更trip_cost功能，增加spending_money到最後的花費總額裏頭。

# %%
def hotel_cost(nights):
  return 140 * nights

def plane_ride_cost(city):
  if city == "Charlotte":
    return 183
  elif city == "Tampa":
    return 220
  elif city == "Pittsburgh":
    return 222
  elif city == "Los Angeles":
    return 475

def rental_car_cost(days):
  cost = days * 40
  if days >= 7:
    cost -= 50
  elif days >= 3:
    cost -= 20
  return cost

#### 從這裡開始寫

def trip_cost(

# %% [markdown]
# #### 試看看 不要直接看答案
#
# def hotel_cost(nights):
#   return 140 * nights
#
# def plane_ride_cost(city):
#   if city == "Charlotte":
#     return 183
#   elif city == "Tampa":
#     return 220
#   elif city == "Pittsburgh":
#     return 222
#   elif city == "Los Angeles":
#     return 475
#
# def rental_car_cost(days):
#   cost = days * 40
#   if days >= 7:
#     cost -= 50
#   elif days >= 3:
#     cost -= 20
#   return cost
#
# def trip_cost(city, days, spending_money):
#   return rental_car_cost(days) + hotel_cost(days) + plane_ride_cost(city) + spending_money
#
# #trip_cost('Pittsburgh', 50, 1000)

# %% [markdown]
# # Learn 7/7
#
# ## 休個假吧~
#
# ### 計劃你的旅程！
# 幹得不錯！ 現在你把它放在一起，讓我們一起去旅行吧。 如果我們去了洛杉磯(Los Angeles)5天，又規劃了大概600美元的額外消費，會花多少錢？
#
# # Instructions 7/7
# 透過前面的程式，把trip_cost("Los Angeles", 5, 600))印出來，就可以快速地得到規劃行程要花多少錢呢~

# %%
def hotel_cost(nights):
  return 140 * nights

def plane_ride_cost(city):
  if city == "Charlotte":
    return 183
  elif city == "Tampa":
    return 220
  elif city == "Pittsburgh":
    return 222
  elif city == "Los Angeles":
    return 475

def rental_car_cost(days):
  cost = days * 40
  if days >= 7:
    cost -= 50
  elif days >= 3:
    cost -= 20
  return cost

def trip_cost(city, days, spending_money):
  return rental_car_cost(days) + hotel_cost(days) + plane_ride_cost(city) + spending_money

#從這裡開始練習

# %% [markdown]
# #### 試看看 不要直接看答案
#
# def hotel_cost(nights):
#   return 140 * nights
#
# def plane_ride_cost(city):
#   if city == "Charlotte":
#     return 183
#   elif city == "Tampa":
#     return 220
#   elif city == "Pittsburgh":
#     return 222
#   elif city == "Los Angeles":
#     return 475
#
# def rental_car_cost(days):
#   cost = days * 40
#   if days >= 7:
#     cost -= 50
#   elif days >= 3:
#     cost -= 20
#   return cost
#
# def trip_cost(city, days, spending_money):
#   return rental_car_cost(days) + hotel_cost(days) + plane_ride_cost(city) + spending_money
#
# print (trip_cost("Los Angeles", 5, 600))
